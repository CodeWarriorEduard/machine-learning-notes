# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The data that we will use in a neural network will always be held in a multidimensional arrays.

# %%
print("Python List operations:")
a = [1,2,3]
b = [4,5,6]

print("a+b:", a+b)
try:
    print(a*b)
except:
    print("a*b is not valid")
print()
# Out:
# Python List operations:
# a+b: [1, 2, 3, 4, 5, 6]
# a*b is not valid

# %% [markdown]
# ### Using numpy

# %%
a = np.array([1,2,3]) # one-dimensional array
b = np.array([4,5,6])
print("shape: \n", a.shape)
print("a+b", a+b)
print("a*b", a*b)
# Out:
# shape:
#  (3,)
# a+b [5 7 9]
# a*b [ 4 10 18]

# %%
# Asignamos un vector de dos dimensiones
a = np.array([[1,2],[3,4]]) # Multidimensional array (2,2)
print(a.shape)
print("a:")
print(a)
print('a.sum(axis=0):', a.sum(axis=0))
print('a.sum(axis=1):', a.sum(axis=1))
# Out:
# (2, 2)
# a:
# [[1 2]
#  [3 4]]
# a.sum(axis=0): [4 6]
# a.sum(axis=1): [3 7]

# %% [markdown]
# ## We can add one-dimensional arrays with 2D arrays.

# %%
a = np.array([[2,3,4],[5,6,7]])
b = np.array([20,21,22])

print("a+b: \n",a+b)
# Out:
# a+b:
#  [[22 24 26]
#  [25 27 29]]

# %% [markdown]
# ### Funciones básicas en NumPy

# %% [markdown]
# ## SQUARE FUNCTION

# %%
def square(x: np.ndarray) -> np.ndarray:
    return np.power(x,2)

input_values = np.arange(-10,10,0.001)
sq = square(input_values)
print(sq)
plt.title('Square function')
plt.plot(input_values,sq)
# Out:
# [100.        99.980001  99.960004 ...  99.940009  99.960004  99.980001]

# %% [markdown]
# ## LEAKY RELU FUNCTION

# %%
def l_relu(x: np.ndarray) -> np.ndarray:
    return np.maximum(0.2*x,x)

l_r = l_relu(np.array([1,6,3]))
input_values = np.arange(-10,10,0.001)
l_r = l_relu(input_values)
print(sq)
plt.title('LEAKY RELU function')
plt.plot(input_values,l_r)
print(l_r)
# Out:
# [100.        99.980001  99.960004 ...  99.940009  99.960004  99.980001]
# [-2.     -1.9998 -1.9996 ...  9.997   9.998   9.999 ]

# %% [markdown]
# ## DERIVATIVES
# we can derivate functions using the following implementation

# %%
from typing import Callable

# %%
def derivate_i(func: Callable[[np.ndarray], np.ndarray], input: np.ndarray, delta:float = 0.001)->np.ndarray:
    return (func(input_ + delta) - func(input_ - delta)) / (2 * delta)

# %% [markdown]
# ## FUNCTIONS WITH MULTIPLE INPUTS

# %%
'''
def multiple_inputs_add(x: np.ndarray, y: np.ndarray, sigma: Array_function) -> float:
    Multiple inputs, forward pass.
    assert x.shape == y.shape
    a = x+y
    return sigma(a)
'''
# Out:
# '\ndef multiple_inputs_add(x: np.ndarray, y: np.ndarray, sigma: Array_function) -> float:\n    Multiple inputs, forward pass.\n    assert x.shape == y.shape\n    a = x+y\n    return sigma(a)\n'
